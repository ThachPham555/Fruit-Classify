# %% [markdown]
# https://towardsdev.com/how-to-find-the-most-dominant-colors-in-an-image-in-python-using-kmeans-clustering-with-source-527ef3e6775f

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget https://post.healthline.com/wp-content/uploads/2020/09/Do_Apples_Affect_Diabetes_and_Blood_Sugar_Levels-732x549-thumbnail-1-732x549.jpg
# Out:
# --2022-08-27 15:29:29--  https://post.healthline.com/wp-content/uploads/2020/09/Do_Apples_Affect_Diabetes_and_Blood_Sugar_Levels-732x549-thumbnail-1-732x549.jpg
# Resolving post.healthline.com (post.healthline.com)... 151.101.2.133, 151.101.66.133, 151.101.130.133, ...
# Connecting to post.healthline.com (post.healthline.com)|151.101.2.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 159070 (155K) [image/jpeg]
# Saving to: ‘Do_Apples_Affect_Diabetes_and_Blood_Sugar_Levels-732x549-thumbnail-1-732x549.jpg’
#
# Do_Apples_Affect_Di 100%[===================>] 155.34K  --.-KB/s    in 0.02s
#
# 2022-08-27 15:29:29 (6.70 MB/s) - ‘Do_Apples_Affect_Diabetes_and_Blood_Sugar_Levels-732x549-thumbnail-1-732x549.jpg’ saved [159070/159070]

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import imutils

# %%
import cv2
from google.colab.patches import cv2_imshow # for image display
clusters = 5 # try changing it

path="/content/drive/MyDrive/Fruit Classify/tao.jpg"
img = cv2.imread(path, 1)
org_img = img
print('Org image shape --> ',img.shape)
# cv2_imshow(img)
# cv2.destroyAllWindows()
# Out:
# Org image shape -->  (640, 900, 3)

# %%
img = imutils.resize(img,height=200)
print('After resizing shape --> ',img.shape)
cv2_imshow(img)
cv2.destroyAllWindows()
# Out:
# After resizing shape -->  (200, 281, 3)
# <PIL.Image.Image image mode=RGB size=281x200>

# %%
flat_img = np.reshape(img,(-1,3))
print('After Flattening shape --> ',flat_img.shape)
# cv2_imshow(flat_img)
# Out:
# After Flattening shape -->  (56200, 3)

# %%
kmeans = KMeans(n_clusters=clusters,random_state=0)
kmeans.fit(flat_img)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=5, random_state=0)

# %%
dominant_colors = np.array(kmeans.cluster_centers_,dtype='uint')

percentages = (np.unique(kmeans.labels_,return_counts=True)[1])/flat_img.shape[0]
p_and_c = zip(percentages,dominant_colors)
p_and_c = sorted(p_and_c,reverse=True)

# %%
print(p_and_c)
# Out:
# [(0.6004982206405693, array([246, 246, 246], dtype=uint64)), (0.16708185053380784, array([ 69,  88, 200], dtype=uint64)), (0.10763345195729537, array([ 46,  59, 171], dtype=uint64)), (0.06491103202846975, array([114, 127, 208], dtype=uint64)), (0.05987544483985765, array([196, 201, 222], dtype=uint64))]

# %%
# !pip install webcolors
# Out:
# Requirement already satisfied: webcolors in /usr/local/lib/python3.10/dist-packages (1.13)

# %%
import webcolors
import time
start = time.time()
def closest_colour(requested_colour):
    min_colours = {}
    for key, name in webcolors.CSS3_HEX_TO_NAMES.items():
        r_c, g_c, b_c = webcolors.hex_to_rgb(key)
        rd = (r_c - requested_colour[0]) ** 2
        gd = (g_c - requested_colour[1]) ** 2
        bd = (b_c - requested_colour[2]) ** 2
        min_colours[(rd + gd + bd)] = name
    return min_colours[min(min_colours.keys())]

requested_colour = (141,13,16)
closest_name = closest_colour(requested_colour)

print("closest colour name:", closest_name)
print("Tempo: ", time.time() - start)
# Out:
# closest colour name: darkred
# Tempo:  0.010740518569946289

# %%
block = np.ones((50,50,3),dtype='uint')
plt.figure(figsize=(12,8))
for i in range(clusters):
    plt.subplot(1,clusters,i+1)
    block[:] = p_and_c[i][1][::-1] # we have done this to convert bgr(opencv) to rgb(matplotlib)
    plt.imshow(block)
    plt.xticks([])
    plt.yticks([])
    plt.xlabel(str(round(p_and_c[i][0]*100,2))+'%')

bar = np.ones((50,500,3),dtype='uint')
# plt.figure(figsize=(12,8))
plt.title('Proportions of colors in the image')
# Out:
# Text(0.5, 1.0, 'Proportions of colors in the image')

# %%
start = 0
i = 1
for p,c in p_and_c:
    end = start+int(p*bar.shape[1])
    if i==clusters:
        bar[:,start:] = c[::-1]
    else:
        bar[:,start:end] = c[::-1]
    start = end
    i+=1
plt.imshow(bar)
plt.xticks([])
plt.yticks([])
# Out:
# ([], [])

# %%
rows = 1000
cols = int((org_img.shape[0]/org_img.shape[1])*rows)
img = cv2.resize(org_img,dsize=(rows,cols),interpolation=cv2.INTER_LINEAR)

copy = img.copy()
cv2.rectangle(copy,(rows//2-250,cols//2-90),(rows//2+250,cols//2+110),(255,255,255),-1)

final = cv2.addWeighted(img,0.1,copy,0.9,0)
cv2.putText(final,'Most Dominant Colors in the Image',(rows//2-230,cols//2-40),cv2.FONT_HERSHEY_DUPLEX,0.8,(0,0,0),1,cv2.LINE_AA)


start = rows//2-220
for i in range(5):
    end = start+70
    final[cols//2:cols//2+70,start:end] = p_and_c[i][1]
    cv2.putText(final,str(i+1),(start+25,cols//2+45),cv2.FONT_HERSHEY_DUPLEX,1,(255,255,255),1,cv2.LINE_AA)
    start = end+20

plt.show()

cv2_imshow(final)
cv2.waitKey(0)
cv2.destroyAllWindows()
# cv2.imwrite('output.png',final)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x790>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import imutils
filepath="/content/drive/MyDrive/Fruit Classify/cam.jpg"

def color_of_image(filepath):
  clusters = 3
  img = cv2.imread(filepath)
  org_img = img.copy()
  img = imutils.resize(img,height=200)
  flat_img = np.reshape(img,(-1,3))
  kmeans = KMeans(n_clusters=clusters,random_state=0)
  kmeans.fit(flat_img)
  dominant_colors = np.array(kmeans.cluster_centers_,dtype='uint')
  percentages = (np.unique(kmeans.labels_,return_counts=True)[1])/flat_img.shape[0]

  p_and_c = zip(percentages,dominant_colors)
  p_and_c = sorted(p_and_c,reverse=True)


  rows = 1000
  cols = int((org_img.shape[0]/org_img.shape[1])*rows)
  img = cv2.resize(org_img,dsize=(rows,cols),interpolation=cv2.INTER_LINEAR)

  copy = img.copy()
  cv2.rectangle(copy,(rows//2-250,cols//2-90),(rows//2+100,cols//2+110),(255,255,255),-1)

  final = cv2.addWeighted(img,0.1,copy,0.9,0)
  cv2.putText(final,'Most Dominant Colors',(rows//2-230,cols//2-40),cv2.FONT_HERSHEY_DUPLEX,0.8,(0,0,0),1,cv2.LINE_AA)


  start = rows//2-220
  for i in range(3):
      end = start+70
      final[cols//2:cols//2+70,start:end] = p_and_c[i][1]
      cv2.putText(final,str(i+1),(start+25,cols//2+45),cv2.FONT_HERSHEY_DUPLEX,1,(255,255,255),1,cv2.LINE_AA)
      start = end+20

  plt.show()

  cv2_imshow(final)
  cv2.waitKey(0)
  cv2.destroyAllWindows()

color_of_image(filepath)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1000x775>

# %%
# Import Module
from PIL import Image

def most_common_used_color(img):
    # Get width and height of Image
    width, height = img.size

    # Initialize Variable
    r_total = 0
    g_total = 0
    b_total = 0

    count = 0

    # Iterate through each pixel
    for x in range(0, width):
        for y in range(0, height):
            # r,g,b value of pixel
            r, g, b = img.getpixel((x, y))

            r_total += r
            g_total += g
            b_total += b
            count += 1

    return (r_total/count, g_total/count, b_total/count)

# Read Image
img = Image.open(r'/content/drive/MyDrive/Fruit Classify/xoaixanh.jpg')

# Convert Image into RGB
img = img.convert('RGB')

# call function
common_color = most_common_used_color(img)

print(common_color)
# Output is (R, G, B)
# Out:
# (202.6051491932629, 214.49158255780108, 184.516569380964)

# %%
# !wget https://afamilycdn.com/Images/Uploaded/Share/2010/08/29/010829gt55.jpg
# Out:
# --2024-05-15 07:34:38--  https://afamilycdn.com/Images/Uploaded/Share/2010/08/29/010829gt55.jpg
# Resolving afamilycdn.com (afamilycdn.com)... 123.30.215.18, 123.30.215.55, 222.255.27.45, ...
# Connecting to afamilycdn.com (afamilycdn.com)|123.30.215.18|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19603 (19K) [image/jpeg]
# Saving to: ‘010829gt55.jpg’
#
# 010829gt55.jpg      100%[===================>]  19.14K  --.-KB/s    in 0.01s
#
# 2024-05-15 07:34:39 (1.63 MB/s) - ‘010829gt55.jpg’ saved [19603/19603]

# %%
# Read Image
img = Image.open(r'/content/drive/MyDrive/Fruit Classify/xoaixanh.jpg')
# Convert Image into RGB
img = img.convert('RGB')

# call function
common_color = most_common_used_color(img)

print(common_color)
# Output is (R, G, B)
# Out:
# (202.6051491932629, 214.49158255780108, 184.516569380964)

# %% [markdown]
# # Xử lý màu

# %%
print(type(p_and_c[0][1]))
# Out:
# <class 'numpy.ndarray'>

# %%
import numpy as np
# print(type(p_and_c))
image=[]
for i in range(len(p_and_c)):
  image.append(p_and_c[i][1])

# %%
image
# Out:
# [array([252, 252, 252], dtype=uint64),
#  array([ 72, 151, 120], dtype=uint64),
#  array([105, 181, 153], dtype=uint64),
#  array([ 46, 126,  94], dtype=uint64),
#  array([184, 210, 199], dtype=uint64)]

# %%
print(type(image[1]))
# Out:
# <class 'numpy.ndarray'>

# %%
for i in range(len(image)):
  image[i]=(image[i].tolist())

# %%
print(type(image[0]))
# Out:
# <class 'list'>

# %%
image
# Out:
# [[252, 252, 252],
#  [72, 151, 120],
#  [105, 181, 153],
#  [46, 126, 94],
#  [184, 210, 199]]

# %%
for i in range(len(image)):
  image[i].reverse()

# %%
image
# Out:
# [[252, 252, 252],
#  [120, 151, 72],
#  [153, 181, 105],
#  [94, 126, 46],
#  [199, 210, 184]]

# %%
import webcolors
def get_colour_name(requested_colour):
    try:
        closest_name = actual_name = webcolors.rgb_to_name(requested_colour)
    except ValueError:
        closest_name = closest_colour(requested_colour)
        actual_name = None
    return actual_name, closest_name

# %%
get_colour_name(187, 56, 40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-eb7c4ca7a454> in <cell line: 1>()
# ----> 1 get_colour_name(187, 56, 40)
#
# TypeError: get_colour_name() takes 1 positional argument but 3 were given

# %%
get_colour_name((255,255,224))
# Out:
# ('lightyellow', 'lightyellow')
